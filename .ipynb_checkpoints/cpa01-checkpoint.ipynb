# %% [markdown]
# - running the Jupyter notebook and showing the markdown and code cells you created (Jupyter)
# - describe your dataset and the questions you were asking, and show the pandas code you wrote to read it in and show the columns and index and the table itself(pandas.read_csv)
# - show a pivot table you created and interpret it (pandas.pivot_table)
# - show the plot you made from the pivot table (pandas,plot) the plot should have labels on the axes and a title and a legend
# - show your use of groupby and interpret the results (pandas.groupby)
# - describe what your analysis tells you about the questions you asked (pandas.analysis)
# - upload links to the github repository and a link t your Zoom movie to the CPA01 problem on the Master-Programs site (with PIN 7297444)
#
#
#
# - https://fiscaldata.treasury.gov/datasets/treasury-reporting-rates-exchange/treasury-reporting-rates-of-exchange

# %%
import numpy as np
import pandas as pd
from matplotlib import pyplot as plt

# %%
df = pd.read_csv('data.csv')
df
# Out:
#       Record Date        Country Currency Country - Currency Description  \
# 0      2021-12-31    Afghanistan  Afghani            Afghanistan-Afghani
# 1      2021-12-31    Afghanistan  Afghani            Afghanistan-Afghani
# 2      2021-12-31        Albania      Lek                    Albania-Lek
# 3      2021-12-31        Algeria    Dinar                  Algeria-Dinar
# 4      2021-12-31         Angola   Kwanza                  Angola-Kwanza
# ...           ...            ...      ...                            ...
# 15741  2001-03-31        Vietnam     Dong                   Vietnam-Dong
# 15742  2001-03-31  Western Samoa     Tala             Western Samoa-Tala
# 15743  2001-03-31          Yemen     Rial                     Yemen-Rial
# 15744  2001-03-31         Zambia   Kwacha                  Zambia-Kwacha
# 15745  2001-03-31       Zimbabwe   Dollar                Zimbabwe-Dollar
#
#        Exchange Rate Effective Date  Source Line Number  Fiscal Year  \
# 0            103.400     2021-12-31                 1.0       2022.0
# 1             91.390     2022-02-15                 2.0       2022.0
# 2            105.950     2021-12-31                 3.0       2022.0
# 3            138.284     2021-12-31                 4.0       2022.0
# 4            562.440     2021-12-31                 5.0       2022.0
# ...              ...            ...                 ...          ...
# 15741      14562.000            NaN               178.0       2001.0
# 15742          3.280            NaN               179.0       2001.0
# 15743        165.000            NaN               180.0       2001.0
# 15744       3520.000            NaN               181.0       2001.0
# 15745         80.000            NaN               182.0       2001.0
#
#        Fiscal Quarter Number  Calendar Year  Calendar Quarter Number  \
# 0                        1.0         2021.0                      4.0
# 1                        1.0         2021.0                      4.0
# 2                        1.0         2021.0                      4.0
# 3                        1.0         2021.0                      4.0
# 4                        1.0         2021.0                      4.0
# ...                      ...            ...                      ...
# 15741                    2.0         2001.0                      1.0
# 15742                    2.0         2001.0                      1.0
# 15743                    2.0         2001.0                      1.0
# 15744                    2.0         2001.0                      1.0
# 15745                    2.0         2001.0                      1.0
#
#        Calendar Month Number  Calendar Day Number
# 0                       12.0                 31.0
# 1                       12.0                 31.0
# 2                       12.0                 31.0
# 3                       12.0                 31.0
# 4                       12.0                 31.0
# ...                      ...                  ...
# 15741                    3.0                 31.0
# 15742                    3.0                 31.0
# 15743                    3.0                 31.0
# 15744                    3.0                 31.0
# 15745                    3.0                 31.0
#
# [15746 rows x 13 columns]

# %%
df = df[df['Calendar Year'] >= 2003]
df['Currency'] = df['Currency'].str.lower()
df['Country'] = df['Country'].str.lower()
group = df.groupby(['Country', 'Currency', 'Calendar Year'])['Exchange Rate'].agg([ np.min, np.mean, np.max]).round(2)
# Out:
# /var/folders/j2/y2nlb_3j2jj4y6sk6y40jf040000gn/T/ipykernel_3958/3248693723.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['Currency'] = df['Currency'].str.lower()
# /var/folders/j2/y2nlb_3j2jj4y6sk6y40jf040000gn/T/ipykernel_3958/3248693723.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['Country'] = df['Country'].str.lower()

# %%
group
# Out:
#                                      amin   mean    amax
# Country     Currency Calendar Year
# afghanistan afghani  2003.0         40.30  46.70   49.25
#                      2004.0         45.21  49.61   57.69
#                      2005.0         45.21  46.48   50.30
#                      2006.0         50.30  50.30   50.30
#                      2007.0         49.53  49.98   50.30
# ...                                   ...    ...     ...
# zimbabwe    rtgs     2013.0          1.00   1.00    1.00
#                      2014.0          1.00   1.00    1.00
#                      2019.0          6.38  12.44   16.28
#                      2020.0         25.16  62.78   81.44
#                      2021.0         81.87  95.37  120.92
#
# [3675 rows x 3 columns]

# %%
group = group.reset_index(level=['Currency'])
group
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# ~/opt/anaconda3/lib/python3.9/site-packages/pandas/core/indexes/multi.py in _get_level_number(self, level)
#    1522         try:
# -> 1523             level = self.names.index(level)
#    1524         except ValueError as err:
#
# ValueError: 'Currency' is not in list
#
# The above exception was the direct cause of the following exception:
#
# KeyError                                  Traceback (most recent call last)
# /var/folders/j2/y2nlb_3j2jj4y6sk6y40jf040000gn/T/ipykernel_3958/4251984249.py in <module>
# ----> 1 group = group.reset_index(level=['Currency'])
#       2 group
#
# ~/opt/anaconda3/lib/python3.9/site-packages/pandas/util/_decorators.py in wrapper(*args, **kwargs)
#     309                     stacklevel=stacklevel,
#     310                 )
# --> 311             return func(*args, **kwargs)
#     312
#     313         return wrapper
#
# ~/opt/anaconda3/lib/python3.9/site-packages/pandas/core/frame.py in reset_index(self, level, drop, inplace, col_level, col_fill)
#    5748             if not isinstance(level, (tuple, list)):
#    5749                 level = [level]
# -> 5750             level = [self.index._get_level_number(lev) for lev in level]
#    5751             if len(level) < self.index.nlevels:
#    5752                 new_index = self.index.droplevel(level)
#
# ~/opt/anaconda3/lib/python3.9/site-packages/pandas/core/frame.py in <listcomp>(.0)
#    5748             if not isinstance(level, (tuple, list)):
#    5749                 level = [level]
# -> 5750             level = [self.index._get_level_number(lev) for lev in level]
#    5751             if len(level) < self.index.nlevels:
#    5752                 new_index = self.index.droplevel(level)
#
# ~/opt/anaconda3/lib/python3.9/site-packages/pandas/core/indexes/multi.py in _get_level_number(self, level)
#    1524         except ValueError as err:
#    1525             if not is_integer(level):
# -> 1526                 raise KeyError(f"Level {level} not found") from err
#    1527             elif level < 0:
#    1528                 level += self.nlevels
#
# KeyError: 'Level Currency not found'

# %%
group_pt =  pd.pivot_table(group, values='mean', index=["Calendar Year"], columns=["Country"])
group_pt
# Out:
# Country        afghanistan  albania  algeria  angola  antigua  \
# Calendar Year
# 2003.0               46.70   116.64    77.08   72.99      NaN
# 2004.0               49.61   102.62    72.18   83.22      NaN
# 2005.0               46.48    99.90    72.96   86.37      NaN
# 2006.0               50.30    96.90    71.50   80.25      NaN
# 2007.0               49.98    89.20    68.22   75.00      NaN
# 2008.0               47.30    91.50    66.86   75.00      NaN
# 2009.0               48.42    95.73    71.51   75.00      NaN
# 2010.0               46.02   106.87    73.27   90.00      NaN
# 2011.0               46.42   101.87    73.18   93.75      NaN
# 2012.0               50.12   107.56    76.74   95.00      NaN
# 2013.0               55.54   105.78    79.46   95.00      NaN
# 2014.0               57.24   107.40    81.84   98.75      NaN
# 2015.0               62.32   126.20   102.15  128.50      2.7
# 2016.0               67.13   123.88   109.38  167.50      2.7
# 2017.0               67.49   116.62   111.23  170.00      2.7
# 2018.0               72.56   107.26   116.77  265.00      2.7
# 2019.0               77.46   109.60   119.21  372.50      2.7
# 2020.0               76.28   108.30   128.77  600.99      NaN
# 2021.0               92.99   104.60   135.50  584.97      NaN
#
# Country        antigua & barbuda  argentina  armenia  australia  austria  ...  \
# Calendar Year                                                             ...
# 2003.0                       2.7       2.98   579.70       1.50    0.860  ...
# 2004.0                       2.7       2.94   531.00       1.36    0.795  ...
# 2005.0                       2.7       2.94   466.69       1.32    3.590  ...
# 2006.0                       2.7       3.08   410.00       1.31    6.375  ...
# 2007.0                       2.7       3.11   333.25       1.16    6.340  ...
# 2008.0                       2.7       3.29   320.00       1.34    6.320  ...
# 2009.0                       2.7       3.75   370.00       1.19    0.720  ...
# 2010.0                       2.7       3.93   372.50       1.08    0.780  ...
# 2011.0                       2.7       4.15   371.25       0.98    0.730  ...
# 2012.0                       2.7       4.61   400.75       0.98    0.770  ...
# 2013.0                       2.7       5.70   409.75       1.06    0.750  ...
# 2014.0                       2.7       8.22   425.00       1.14    0.770  ...
# 2015.0                       NaN      10.07   476.00       1.35    0.910  ...
# 2016.0                       NaN      15.20   478.50       1.34    0.910  ...
# 2017.0                       NaN      17.14   482.25       1.29    0.870  ...
# 2018.0                       NaN      31.31   482.50       1.36    0.850  ...
# 2019.0                       2.7      50.87   478.75       1.44    0.890  ...
# 2020.0                       2.7      78.69   490.75       1.41    0.890  ...
# 2021.0                       2.7     102.38   498.75       1.35    0.870  ...
#
# Country        united kingdom  uruguay  uzbekistan  vanuatu     venezuela  \
# Calendar Year
# 2003.0                  0.600    28.11      987.00   119.85  1.600000e+03
# 2004.0                  0.540    28.17     1024.25   111.55  1.977500e+03
# 2005.0                  0.550    24.29     1110.50   108.91  2.150000e+03
# 2006.0                  0.540    24.02     1228.75   107.73  2.150000e+03
# 2007.0                  0.500    23.26     1270.75    95.45  1.613040e+03
# 2008.0                  0.600    22.25     1339.00   101.66  2.150000e+00
# 2009.0                  0.610    21.46     1487.00   100.47  2.150000e+00
# 2010.0                  0.650    20.24     1610.50    96.27  3.020000e+00
# 2011.0                  0.630    19.30     1740.25    90.91  3.450000e+00
# 2012.0                  0.630    19.95     1935.75    91.22  4.300000e+00
# 2013.0                  0.640    20.44     2153.50    93.81  6.300000e+00
# 2014.0                  0.610    23.49     2370.00    96.15  6.300000e+00
# 2015.0                  0.660    27.87     2662.25   106.85  6.300000e+00
# 2016.0                  0.760    30.04     3066.25   107.59  5.569600e+02
# 2017.0                  0.760    28.72     5921.00   105.56  2.509840e+03
# 2018.0                  0.760    31.24     8102.50   109.14  1.074653e+05
# 2019.0                  0.775    37.31     8952.50   113.02  1.446411e+05
# 2020.0                  0.780    42.63    10117.98   113.30  4.253885e+05
# 2021.0                  0.730    43.82    10624.63   109.54  1.063360e+06
#
# Country         vietnam  western samoa   yemen    zambia      zimbabwe
# Calendar Year
# 2003.0         15525.25           2.87  183.00  4662.500  3.942750e+03
# 2004.0         15744.50           2.70  184.25  4672.500  5.528030e+03
# 2005.0         15857.00           2.63  191.25  4183.750  3.690550e+04
# 2006.0         15985.00           2.67  196.75  3750.000  4.421837e+04
# 2007.0         16106.00           2.46  198.50  3923.750  5.541930e+06
# 2008.0         16542.75           2.62  199.00  4348.750  7.540000e+09
# 2009.0         17868.00           2.65  202.50  4843.750  6.000000e+09
# 2010.0         19270.00           2.39  218.75  4916.250  1.000000e+00
# 2011.0         20550.00           2.22  217.00  4867.500  1.000000e+00
# 2012.0         21000.00           2.19  214.50  5217.500  1.000000e+00
# 2013.0         21025.00           2.24  214.50  1345.330  1.000000e+00
# 2014.0         21250.00           2.28  214.50     6.170  1.000000e+00
# 2015.0         22036.25           2.49  214.50  2732.275  1.000000e+00
# 2016.0         22410.00           2.47  241.50  2732.595  1.000000e+00
# 2017.0         22728.25           2.44  250.50  2732.295  1.000000e+00
# 2018.0         23066.00           2.50  461.25  2732.940  1.000000e+00
# 2019.0         23218.50           2.54  480.00    13.540  6.555000e+00
# 2020.0         23267.75           2.57  480.00    19.330  6.278000e+01
# 2021.0         22900.75           2.52  540.00    19.440  9.537000e+01
#
# [19 rows x 213 columns]

# %%
group_pt[['afghanistan','nepal', 'india','bangladesh', 'sri lanka', 'pakistan', 'maldives']].plot(figsize=(15,10))
plt.grid()
plt.title("USD to South Asian Currency conversion rates")
# Out:
# Text(0.5, 1.0, 'USD to South Asian Currency conversion rates')

# %%
below_fhund = group[group['mean'] < 5]

below_fhund =  pd.pivot_table(group, values='mean', index=["Calendar Year"], columns=["Country"])

below_fhund.plot(figsize=(15,10))
# Out:
# <AxesSubplot:xlabel='Calendar Year'>
